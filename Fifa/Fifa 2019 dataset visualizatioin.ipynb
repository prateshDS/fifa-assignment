# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max.column', None)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
fifa_data = pd.read_csv("data.csv")

# %% [markdown]
# # Remove unncessory columns like unnamed, NaN(if has much NaN)

# %%
fifa_data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fifa_data.drop(['Unnamed: 0','Loaned From'], axis='columns', inplace=True)

# %%
fifa_data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# # Analyze all player wages

# %%
fifa_data['Converted Wages'] = fifa_data.Wage.str.replace('€|K','').astype(float).apply(lambda x : x * 1000)

# %%
sns.distplot(fifa_data['Converted Wages'], kde=False)

# %%
fifa_data['Converted Wages'].value_counts().head(20)
# Out:
# 1000.0     4900
# 2000.0     2827
# 3000.0     1857
# 4000.0     1255
# 5000.0      869
# 6000.0      682
# 7000.0      488
# 8000.0      423
# 9000.0      328
# 10000.0     319
# 11000.0     292
# 12000.0     256
# 0.0         241
# 13000.0     227
# 15000.0     200
# 14000.0     188
# 17000.0     161
# 18000.0     152
# 16000.0     136
# 20000.0     134
# Name: Converted Wages, dtype: int64

# %% [markdown]
# # Analyse which Club or National Team has the best-rated players

# %%
teams = fifa_data.Nationality.unique()

# %%
teams
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
total_countries = len(teams)
total_countries
# Out:
# 164

# %%
best_rated_players = fifa_data[fifa_data.groupby('Nationality')['Overall'].apply(lambda x: x > 85)].head(10)

# %%
best_rated_players
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
sns.distplot(best_rated_players.Overall)

# %% [markdown]
# # Note: Above observation is of top 10 Player's who has over all rating greater then 85

# %% [markdown]
# # Assess the strength of a team at a particular position

# %%
strong_teams = fifa_data.groupby('Nationality')['Converted Wages'].sum().sort_values(ascending=False)

# %%
strong_teams
# Out:
# Nationality
# Spain        17498000.0
# England      16526000.0
# Brazil       14703000.0
# France       12845000.0
# Germany      11548000.0
#                 ...
# Ethiopia         1000.0
# Andorra          1000.0
# Jordan           1000.0
# Indonesia        1000.0
# India               0.0
# Name: Converted Wages, Length: 164, dtype: float64

# %%
sns.distplot(strong_teams, kde= False)

# %% [markdown]
# # If sum of all wages of the particular country is high, then that means they are paying to quality players

# %% [markdown]
# # Analyse the team with the best dribbling speed

# %%
avg = fifa_data.groupby('Club')['Dribbling'].mean().sort_values(ascending =False)

# %%
len(avg)
# Out:
# 651

# %%
avg
# Out:
# Club
# Juventus               69.520000
# Paris Saint-Germain    68.833333
# Napoli                 68.640000
# Liverpool              68.212121
# Borussia Dortmund      68.151515
#                          ...
# Carlisle United        45.666667
# Stevenage              45.500000
# Itagüí Leones FC       45.384615
# Limerick FC            43.421053
# Bray Wanderers         43.000000
# Name: Dribbling, Length: 651, dtype: float64

# %%
sns.distplot(avg, kde=False)

# %% [markdown]
# # Note: Juventus club has most dribbling speed

# %% [markdown]
# # Co-relate between Age and Overall rating

# %%
fifa_data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa_data[['Age','Overall']].corr()
# Out:
#              Age  Overall
# Age      1.00000  0.45235
# Overall  0.45235  1.00000

# %%
sns.jointplot(x = fifa_data['Age'], y = fifa_data['Overall'],data=fifa_data, kind='hex')

# %% [markdown]
# # seems like player age group between 18 to 30 has most overall skill between 55 to 75

# %% [markdown]
# # 6. Co-relate between Age and Nationality

# %%
fig = plt.figure(figsize =(20,30))

sns.barplot(x = 'Age', y = 'Nationality',data=fifa_data)

# %% [markdown]
# # I have used a barplot, to categorize countries, and to show the age of the players

# %% [markdown]
# # 7. Total number of right foot and left foot players

# %%
fifa_data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
preferred_foot_players = fifa_data['Preferred Foot'].value_counts()

# %%
preferred_foot_players.values
# Out:
# array([13948,  4211], dtype=int64)

# %%
sns.countplot('Preferred Foot', data=fifa_data)

# %% [markdown]
# # Most players preferred foot is Right i.e approx 14000

# %% [markdown]
# # 8. Distribution of the positions of players

# %%
position_of_players = fifa_data.Position.value_counts()

# %%
plt.hist(x=position_of_players.values)
# Out:
# (array([9., 6., 1., 1., 2., 3., 2., 0., 1., 2.]),
#  array([  15. ,  228.7,  442.4,  656.1,  869.8, 1083.5, 1297.2, 1510.9,
#         1724.6, 1938.3, 2152. ]),
#  <a list of 10 Patch objects>)

# %%
fifa_data.Position.unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %% [markdown]
# # 9. Figure out when the contracts of players will expire in Fifa 2019.

# %%
fifa_data.groupby('Contract Valid Until')['Name'].count()
# Out:
# Contract Valid Until
# 2018             886
# 2019            4819
# 2020            4027
# 2021            4360
# 2022            1477
# 2023            1053
# 2024              23
# 2025               7
# 2026               2
# Dec 1, 2019        2
# Dec 31, 2018     144
# Dec 31, 2019       3
# Feb 27, 2020       1
# Jan 1, 2019       51
# Jan 11, 2019       1
# Jan 12, 2019       5
# Jan 15, 2019       1
# Jan 18, 2019       1
# Jan 2, 2019        6
# Jan 20, 2019       1
# Jan 25, 2019       3
# Jan 3, 2019        1
# Jan 30, 2019       1
# Jan 31, 2019      13
# Jan 4, 2019        1
# Jan 5, 2019        6
# Jan 6, 2019        4
# Jan 7, 2019        3
# Jun 1, 2019        1
# Jun 30, 2019     931
# Jun 30, 2020      14
# May 31, 2019      60
# May 31, 2020       2
# May 4, 2019        1
# Nov 30, 2018       2
# Oct 14, 2019       5
# Name: Name, dtype: int64

# %%
import plotly.express as exp

# %%
fig1 = plt.figure(figsize =(20,15))
sns.countplot(y='Contract Valid Until', data=fifa_data)

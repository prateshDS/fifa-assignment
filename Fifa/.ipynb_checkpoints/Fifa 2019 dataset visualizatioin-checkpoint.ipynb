# %%
import pandas as pd
import seaborn as sns
pd.set_option('display.max.column', None)

# %%
fifa_data = pd.read_csv("data.csv")

# %% [markdown]
# # Remove unncessory columns like unnamed, NaN(if has much NaN)

# %%
fifa_data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fifa_data.drop(['Unnamed: 0','Loaned From'], axis='columns', inplace=True)

# %%
fifa_data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# # Analyze all player wages

# %%
fifa_data['Converted Wages'] = fifa_data.Wage.str.replace('€|K','').astype(float).apply(lambda x : x * 1000)

# %%
sns.distplot(fifa_data['Converted Wages'], kde=False)

# %%
fifa_data['Converted Wages'].value_counts()
# Out:
# 1000.0      4900
# 2000.0      2827
# 3000.0      1857
# 4000.0      1255
# 5000.0       869
#             ...
# 380000.0       1
# 230000.0       1
# 565000.0       1
# 200000.0       1
# 245000.0       1
# Name: Converted Wages, Length: 144, dtype: int64

# %% [markdown]
# # Analyse which Club or National Team has the best-rated players

# %%
teams = fifa_data.Nationality.unique()

# %%
teams
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
total_countries = len(teams)
total_countries
# Out:
# 164

# %%
best_rated_players = fifa_data[fifa_data.groupby('Nationality')['Overall'].apply(lambda x: x > 90)]

# %%
best_rated_players
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %% [markdown]
# # Assess the strength of a team at a particular position

# %%
strong_teams = fifa_data.groupby('Nationality')['Converted Wages'].sum().sort_values(ascending=False)

# %%
strong_teams
# Out:
# Nationality
# Spain        17498000.0
# England      16526000.0
# Brazil       14703000.0
# France       12845000.0
# Germany      11548000.0
#                 ...
# Ethiopia         1000.0
# Andorra          1000.0
# Jordan           1000.0
# Indonesia        1000.0
# India               0.0
# Name: Converted Wages, Length: 164, dtype: float64

# %%
sns.distplot(strong_teams, kde= False)

# %% [markdown]
# # Analyse the team with the best dribbling speed

# %%
avg = fifa_data.groupby('Nationality')['Dribbling'].mean().sort_values(ascending =False)

# %%
len(avg)
# Out:
# 164

# %%
avg
# Out:
# Nationality
# United Arab Emirates    80.000000
# Libya                   73.750000
# Fiji                    72.000000
# Ethiopia                70.000000
# Tanzania                69.666667
#                           ...
# Latvia                  32.500000
# Grenada                 30.000000
# Qatar                   28.000000
# New Caledonia           23.000000
# Oman                    14.000000
# Name: Dribbling, Length: 164, dtype: float64

# %% [markdown]
# # Co-relate between Age and Overall rating

# %%
fifa_data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa_data[['Age','Overall']]
# Out:
#        Age  Overall
# 0       31       94
# 1       33       94
# 2       26       92
# 3       27       91
# 4       27       91
# ...    ...      ...
# 18202   19       47
# 18203   19       47
# 18204   16       47
# 18205   17       47
# 18206   16       46
#
# [18207 rows x 2 columns]

# %%
sns.jointplot(x = fifa_data['Age'], y = fifa_data['Overall'],data=fifa_data, kind='reg')

# %% [markdown]
# # seems like player age group between 20 to 30 has most overall skill between 55 to 75

# %% [markdown]
# # 6. Co-relate between Age and Nationality

# %%
sns.jointplot(x = fifa_data['Age'].astype(float), y = fifa_data['Nationality'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-8cde6a6ec437> in <module>
# ----> 1 sns.jointplot(x = fifa_data['Age'].astype(float), y = fifa_data['Nationality'])
#
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2292         marginal_kws.setdefault("kde", False)
#    2293         marginal_kws.setdefault("color", color)
# -> 2294         grid.plot_marginals(distplot, **marginal_kws)
#    2295
#    2296     elif kind.startswith("hex"):
#
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1811         kwargs["vertical"] = True
#    1812         plt.sca(self.ax_marg_y)
# -> 1813         func(self.y, **kwargs)
#    1814
#    1815         return self
#
# ...

# %%
fifa_data['Age'].astype(int)
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int32

# %%
fifa_data[['Age','Overall']].corr()
# Out:
#              Age  Overall
# Age      1.00000  0.45235
# Overall  0.45235  1.00000

# %%
sns.heatmap(fifa_data.corr())
